# %%
# This file converts the text formatted data to csv files and explore the various features of dataset

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Converting the Dataset from text format to csv format and saving the files

# %%
rows = []
file_name = ['train_data', 'test_data_solution']
with open(file_name[1]+'.txt', 'r') as train_dataset:
  for line in train_dataset:
    line.strip()
    id, title, genre, description = line.split(':::')
    rows.append({'Id': id, 'Title': title, 'Genre': genre, 'Description': description})

df = pd.DataFrame(rows)
df.to_csv(file_name[1]+'.csv', index=False)

# %%
rows = []

with open('test_data.txt', 'r') as test_dataset:
  for line in test_dataset:
    line.strip()
    id, title, description = line.split(':::')
    rows.append({'Id': id, 'Title': title, 'Description': description})

df = pd.DataFrame(rows)
df.to_csv('test_data.csv', index=False)

# %%
# Checking if dataset has missing values
print(df.isnull().sum())
# Out:
# Id             0
# Title          0
# Genre          0
# Description    0
# dtype: int64

# %%
print(df.describe())
# Out:
#             Id                        Title    Genre  \
# count    54200                        54200    54200
# unique   54200                        54200       27
# top     54200    Curitiba Zero Grau (2010)    drama
# freq         1                            1    13612
#
#                                               Description Genre_List
# count                                               54200      54200
# unique                                              54072         27
# top      Grammy - music award of the American academy ...  [ drama ]
# freq                                                   10      13612

# %%
print(df.head())
# Out:
#    Id                          Title          Genre  \
# 0  1           Edgar's Lunch (1998)       thriller
# 1  2       La guerra de papá (1977)         comedy
# 2  3    Off the Beaten Track (2010)    documentary
# 3  4         Meu Amigo Hindu (2015)          drama
# 4  5              Er nu zhai (1955)          drama
#
#                                          Description
# 0   L.R. Brane loves his life - his car, his apar...
# 1   Spain, March 1964: Quico is a very naughty ch...
# 2   One year in the life of Albin and his family ...
# 3   His father has died, he hasn't spoken with hi...
# 4   Before he was known internationally as a mart...

# %%
print(df['Genre'].unique())
# Out:
# [' thriller ' ' comedy ' ' documentary ' ' drama ' ' horror ' ' short '
#  ' western ' ' family ' ' sport ' ' romance ' ' war ' ' game-show '
#  ' biography ' ' adult ' ' talk-show ' ' action ' ' music ' ' crime '
#  ' animation ' ' sci-fi ' ' adventure ' ' reality-tv ' ' fantasy '
#  ' mystery ' ' history ' ' news ' ' musical ']

# %%
genre_counts = df['Genre'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
plt.xticks(rotation=45)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-13-0ffeb2a72534>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
